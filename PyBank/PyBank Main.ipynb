# %%
import pandas as pd

# %%
file_1 = "budget_data_1.csv"

file_2 = "budget_data_2.csv"

# %%
#import two files
file_1_df = pd.read_csv(file_1)

file_2_df = pd.read_csv(file_2)

file_2_df.head()
# Out:
#        Date  Revenue
# 0  Jan-2009   943690
# 1  Feb-2009  1062565
# 2  Mar-2009   210079
# 3  Apr-2009  -735286
# 4  May-2009   842933

# %%
#count months
#file_1_df["Date"].value_counts()

file_1_df["Date"].nunique()
# Out:
# 41

# %%
#test is any values overlap
result = file_1_df["Date"].isin(file_2_df["Date"])
result[:1].sum()
# Out:
# 0

# %%
file_2_df
# Out:
#         Date  Revenue
# 0   Jan-2009   943690
# 1   Feb-2009  1062565
# 2   Mar-2009   210079
# 3   Apr-2009  -735286
# 4   May-2009   842933
# 5   Jun-2009   358691
# 6   Jul-2009   914953
# 7   Aug-2009   723427
# 8   Sep-2009  -837468
# 9   Oct-2009  -146929
# 10  Nov-2009   831730
# 11  Dec-2009   917752
# 12  Jan-2010   800038
# 13  Feb-2010  1117103
# 14  Mar-2010   181220
# 15  Apr-2010   120968
# 16  May-2010   844012
# 17  Jun-2010   307468
# 18  Jul-2010   502341
# 19  Aug-2010  -748679
# 20  Sep-2010 -1063151
# 21  Oct-2010   111367
# 22  Nov-2010   889322
# 23  Dec-2010  1028794
# 24  Jan-2011  -705201
# 25  Feb-2011   457393
# 26  Mar-2011   358440
# 27  Apr-2011   110092
# 28  May-2011  1111337
# 29  Jun-2011   691712
# ..       ...      ...
# 56  Sep-2013   339680
# 57  Oct-2013   809253
# 58  Nov-2013   924494
# 59  Dec-2013   998347
# 60  Jan-2014  -524902
# 61  Feb-2014   747765
# 62  Mar-2014   197783
# 63  Apr-2014   131625
# 64  May-2014  1016992
# ...
